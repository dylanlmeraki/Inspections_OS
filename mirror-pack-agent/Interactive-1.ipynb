# %% [markdown]
# Connected to .venv (Python 3.15.0)

# %%
#!/usr/bin/env python3
from __future__ import annotations

import argparse
import json
import sys
from pathlib import Path

ROOT = Path(__file__).resolve().parents[1]
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from acquisition.preflight import resolve_task_inputs


def build_parser() -> argparse.ArgumentParser:
    parser = argparse.ArgumentParser(
        description="Resolve task required_files against workspace inputs and acquisition manifests.",
    )
    parser.add_argument("task_file", help="Path to task manifest YAML")
    parser.add_argument(
        "--workspace-root",
        default=".",
        help="Workspace root containing docs/source_set and acquired/",
    )
    parser.add_argument(
        "--acquired-root",
        default="acquired",
        help="Acquisition output root",
    )
    parser.add_argument(
        "--json",
        action="store_true",
        dest="json_output",
        help="Emit machine-readable JSON only",
    )
    return parser


def main(argv: list[str] | None = None) -> int:
    parser = build_parser()
    args = parser.parse_args(argv)

    report = resolve_task_inputs(
        task_path=Path(args.task_file),
        workspace_root=Path(args.workspace_root),
        acquired_root=Path(args.acquired_root),
    )
    print(json.dumps(report, indent=2))
    return 0 if report["all_resolved"] else 1


if __name__ == "__main__":
    raise SystemExit(main())
# Out:
# usage: ipykernel_launcher.py [-h] [--workspace-root WORKSPACE_ROOT]
#                              [--acquired-root ACQUIRED_ROOT] [--json]
#                              task_file
# ipykernel_launcher.py: error: the following arguments are required: task_file
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# c:\Users\dylan\Downloads\InspectionOS_mirror_file_pack\mirror-pack-agent\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3755: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# No kernel connected
